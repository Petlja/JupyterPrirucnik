# %% [markdown]
# # Приручник за Џупајтер (_Jupyter_)
#
# Пред вама је Приручник за Џупајтер (_Jupyter_), интерактивно радно окружење за извршавање Пајтон програма. У њему је обрађен део курса информатике и рачунарства за 8. разред основне школе у Србији који се односи на визуелизацију и обраду података.
#
# Сваки час је обрађен у једној Џупајтер радној свесци. Први час представља увод у Џупајтер и мало подсећање на основе програмског језика Пајтон, док је осталих петнаест часова подељено у групе од по три часа (два часа обраде градива и један час утврђивања градива).
#
# ## Садржај
#
#
# Уводни час:
#
# * 1. час: [Увод у Џупајтер (_Jupyter_)](J01.ipynb)
#
# Представљање и визуелизација низова података:
#
# * 2. час: [Записивање и приказивање низова података](J02.ipynb)
# * 3. час: [Боје и приказивање низова података](J03.ipynb)
# * 4. час: [Утврђивање градива](J04.ipynb)
#
# Једноставне анализе података:
#
# * 5. час: [Просек низа бројева](J05.ipynb)
# * 6. час: [Проценти и секторски дијаграми](J06.ipynb)
# * 7. час: [Утврђивање градива](J07.ipynb)
#
# Увод у табеларно представљене податке:
#
# * 8. час: [Табеларно представљени подаци](J08.ipynb)
# * 9. час: [Рад са индексираним табелама](J09.ipynb)
# * 10. час: [Утврђивање градива](J10.ipynb)
#
# Учитавање, модификација и упис табела у датотеку:
#
# 11. час: [Учитавање табела из локалних датотека и из удаљених ресурса](J11.ipynb)
# 12. час: [Модификације табеле и записивање табеле у датотеку](J12.ipynb)
# 13. час: [Утврђивање градива](J13.ipynb)
#
# Обрада табеларно представљених података:
#
# 14. час: [Сортирање, филтрирање и фреквенцијска анализа](J14.ipynb)
# 15. час: [Џупајтер и Ексел](J15.ipynb)
# 16. час: [Утврђивање градива](J16.ipynb)
