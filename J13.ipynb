# %% [markdown]
# # 13. час: Утврђивање градива
#
# Сада ћемо мало застати и осврнути се на материјал са последња два часа.

# %% [markdown]
# **Задатак 1.** Изврши ћелију испод, па одговори на следећа питања:

# %%
# изврши ову ћелију
import pandas as pd
import matplotlib.pyplot as plt

podaci = [["Ана",     "ж", 13, 46, 160],
          ["Бојан",   "м", 14, 52, 165],
          ["Влада",   "м", 13, 47, 157],
          ["Гордана", "ж", 15, 54, 165],
          ["Дејан",   "м", 15, 56, 163],
          ["Ђорђе",   "м", 13, 45, 159]]

tabela = pd.DataFrame(podaci)
tabela.columns=["Име", "Пол", "Старост", "Тежина", "Висина"]
tabela1=tabela.set_index("Име")

tabela_po_visini = tabela1.sort_values(by="Висина")

plt.figure(figsize=(10,5))
plt.plot(tabela_po_visini.index, tabela_po_visini["Висина"])
plt.show()
plt.close()

# %% [markdown]
# 1. Зашто крива на дијаграму расте, када то није случај са подацима у листи `podaci`?
# 2. Зашто је сегмент дијаграма на самом крају хоризонталан?
# 2. Шта треба изменити у програму да бисмо добили графикон који опада?

# %% [markdown]
# **Задатак 2.** У наредној ћелији се налазе подаци о неколико ученика. За сваког ученика је наведено његово презиме, име, ЈМБГ, пол, разред који похађа и просек на крају тог разреда:

# %%
# изврши ову ћелију
podaci = [
    ["Петровић",  "Петар", "0308003800019", "м", 8, 4.52],
    ["Јаснић",    "Јасна", "1210003805026", "ж", 8, 5.00],
    ["Аничић",    "Аница", "1105004805019", "ж", 7, 4.11],
    ["Веснић",    "Весна", "2901005705011", "ж", 6, 5.00],
    ["Ђорђевић",  "Ђорђе", "1504005700012", "м", 6, 3.12],
    ["Милошев",   "Милош", "1506004400056", "м", 7, 2.51],
    ["Милошев",   "Петар", "1506004400057", "м", 7, 2.48],
    ["Ненадовић", "Ненад", "2109003800046", "м", 8, 3.58],
    ["Ненадовић", "Јасна", "2109003805021", "ж", 8, 4.21]]

# %% [markdown]
# _(а)_ Додај нову ћелију испод ове, па у њој формирај одговарајућу табелу позивом функције _DataFrame_.

# %% [markdown]
# _(б)_ Прикажи секторским дијаграмом полну структуру ове групе. (Додај нову ћелију испод.)

# %% [markdown]
# _(в)_ Прикажи секторским дијаграмом старосну структуру ове групе узимајући у обзир разред који је ученик завршио. (Додај нову ћелију испод.)

# %% [markdown]
# _(г)_ Коју колону је најбоље одабрати као кључ за индексирање ове табеле? У ћелији испод ове направи нову табелу која се добија индексирањем претходне табеле одабраном колоном.

# %% [markdown]
# _(д)_ Шта мислиш, зашто сваки држављанин наше државе има ЈМБГ?

# %% [markdown]
# _(ђ)_ Направи нову табелу коју чине само ученици осмог разреда.

# %% [markdown]
# _(е)_ Направи нову табелу коју чине само врло добри ученици.

# %% [markdown]
# _(ж)_ Направи нову табелу коју чине само дечаци који нису одлични.

# %% [markdown]
# **Задатак 3.** У ћелији испод налазе се три низа података: списак имена месеци и потом максималне и минималне температуре по месецима које су забележене у Сјеници у периоду 1981-2010. године. (Подаци су преузети са сајта Републичког хидрометеоролошког завода и доступни су на адреси
# http://www.hidmet.gov.rs/latin/meteorologija/stanica_sr.php?moss_id=13369)

# %%
# изврши ову ћелију!
meseci =               ["Јан", "Феб", "Мар", "Апр", "Мај", "Јун", "Јул", "Авг", "Сеп", "Окт", "Нов", "Дец"]
SjenicaMaxPoMesecima = [ 14.0,  19.4,  21.9,  24.3,  28.8,  31.5,  33.5,  32.8,  29.7,  26.5,  20.2,  18.0]
SjenicaMinPoMesecima = [-35.6, -31.0, -25.0,  -8.3,  -6.4,  -3.7,  -0.4,  -1.3,  -9.3, -10.7, -26.2, -29.6]

# %% [markdown]
# Додај нови ред овој табели па у њега упиши максимални температурни распон за сваки месец, који се добија када се од највише забележене температуре одузме најнижа забележена температура.

# %% [markdown]
# **Задатак 4.** Ево трошкова живота једне породице током једне године, по месецима (сви износи су представљени у динарима):
#
#   | Ставка | Јан | Феб | Мар | Апр | Мај | Јун | Јул | Авг | Сеп | Окт | Нов | Дец |
#   |--------|-----|-----|-----|-----|-----|-----|-----|-----|-----|-----|-----|-----|
#   | Станарина | 8.251 | 8.436 | 8.524 | 8.388 | 8.241 | 8.196 | 8.004 | 7.996 | 7.991 | 8.015 | 8.353 | 8.456 |
#   | Струја | 4.321 | 4.530 | 4.115 | 3.990 | 3.985 | 3.726 | 3.351 | 3.289 | 3.295 | 3.485 | 3.826 | 3.834 |
#   | Телефон (фиксни) | 1.425 | 1.538 | 1.623 | 1.489 | 1.521 | 1.485 | 1.491 | 1.399 | 1.467 | 1.531 | 1.410 | 1.385 |
#   | Телефон (мобилни) | 2.181 | 2.235 | 2.073 | 1.951 | 1.989 | 1.945 | 3.017 | 2.638 | 2.171 | 1.831 | 1.926 | 1.833 |
#   | ТВ и интернет | 2.399 | 2.399 | 2.399 | 2.399 | 2.399 | 2.399 | 2.399 | 2.399 | 2.399 | 2.399 | 2.399 | 2.399  |
#   | Превоз | 1.830 | 1.830 | 1.830 | 1.830 | 1.950 | 1.950 | 1.450 | 1.450 | 1.950 | 1.950 | 2.050 | 2.050 |
#   | Храна | 23.250 | 23.780 | 24.019 | 24.117 | 24.389 | 24.571 | 24.736 | 24.951 | 25.111 | 25.389 | 25.531 | 25.923 |
#   | Остало | 4.500 | 3.700 | 5.100 | 3.500 | 2.750 | 4.250 | 7.320 | 8.250 | 3.270 | 4.290 | 3.200 | 8.390 |
#
# У ћелији испод су исти подаци представљени листом:

# %%
# изврши ову ћелију
troskovi = [
  ["Станарина", 8251, 8436, 8524, 8388, 8241, 8196, 8004, 7996, 7991, 8015, 8353, 8456],
  ["Струја", 4321, 4530, 4115, 3990, 3985, 3726, 3351, 3289, 3295, 3485, 3826, 3834],
  ["Телефон (фиксни)", 1425, 1538, 1623, 1489, 1521, 1485, 1491, 1399, 1467, 1531, 1410, 1385],
  ["Телефон (мобилни)", 2181, 2235, 2073, 1951, 1989, 1945, 3017, 2638, 2171, 1831, 1926, 1833],
  ["ТВ и интернет", 2399, 2399, 2399, 2399, 2399, 2399, 2399, 2399, 2399, 2399, 2399, 2399 ],
  ["Превоз", 1830, 1830, 1830, 1830, 1950, 1950, 1450, 1450, 1950, 1950, 2050, 2050],
  ["Храна", 23250, 23780, 24019, 24117, 24389, 24571, 24736, 24951, 25111, 25389, 25531, 25923],
  ["Остало", 4500, 3700, 5100, 3500, 2750, 4250, 7320, 8250, 3270, 4290, 3200, 8390]
]

# %% [markdown]
# _(а)_ Додај нову ћелију испод ове па представи табелу структуром _DataFrame_. Индексирај табелу.

# %% [markdown]
# _(б)_ Додај табели нову врсту "Укупно" па у њу унеси укупне трошкове ове породице по месецима (колико је породица укупно потрошила у јануарну, колико у фебруару итд).

# %% [markdown]
# _(в)_ Додај табели нову колону "Просечно" па у њу унеси просечну потрошњу ове породице по ставкама (колико је породица просечно потрошила на станарину, колико на струју, итд).

# %% [markdown]
# **Задатак 5.** У табели испод су дати подаци о продаји неких производа у пет пословних јединица једне компаније (бројеви представљају број продатих комада у једном месецу):
#
# | Производ       | ПЈ1 | ПЈ2 | ПЈ3 | ПЈ4 | ПЈ5 |
# |----------------|-----|-----|-----|-----|-----|
# | Ципеле         |  5  | 17  |  3  | 11  |  9  |
# | Кошуља         |  8  |  6  |  7  |  4  |  0  |
# | Каиш           |  4  |  1  |  3  |  5  |  1  |
# | Панталоне      |  4  |  2  |  6  |  4  |  5  |
# | Чарапе (пар)   |  8  |  9  |  7  |  4  |  9  |
# | Кравата        |  1  |  0  |  3  |  2  |  4  |
#
# Следећа табела садржи цене ових производа у динарима:
#
# | Производ       | Цена (дин) |
# |----------------|------------|
# | Ципеле         |  11.250  |
# | Кошуља         |   6.500  |
# | Каиш           |   4.750  |
# | Панталоне      |   2.500  |
# | Чарапе (пар)   |     750  |
# | Кравата        |   3.500  |
#
# Ћелија испод садржи податке из ове две табеле предстаљене у облику листе:

# %%
# изврши ову ћелију
proizvodi = [
    ["Ципеле",         5, 17,  3, 11,  9],
    ["Кошуља",         8,  6,  7,  4,  0],
    ["Каиш",           4,  1,  3,  5,  1],
    ["Панталоне",      4,  2,  6,  4,  5],
    ["Чарапе (пар)",   8,  9,  7,  4,  9],
    ["Кравата",        1,  0,  3,  2,  4]]
cene = [
    ["Ципеле",         11250],
    ["Кошуља",          6500],
    ["Каиш",            4750],
    ["Панталоне",       2500],
    ["Чарапе (пар)",     750],
    ["Кравата",         3500]]

# %% [markdown]
# _(а)_ Представи обе табеле структуром _DataFrame_. Индексирај обе табеле.

# %% [markdown]
# _(б)_ Транспонуј табелу са производима и додај јој нову колону "Зарада".

# %% [markdown]
# _(в)_ У колони "Зарада" израчунај зараду сваке пословне јединице у том месецу.

# %% [markdown]
# _(г)_ Сортирај табелу према заради пословних јединица и прикажи зараде дијаграмом.
